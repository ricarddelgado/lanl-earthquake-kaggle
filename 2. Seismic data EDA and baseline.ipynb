# %% [markdown]
# # Seismic data EDA and baseline
#
# Based on the kernel from https://www.kaggle.com/artgor/seismic-data-eda-and-baseline

# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15

import lightgbm as lgb
import xgboost as xgb
import time
import datetime

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold, KFold, RepeatedKFold
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import Ridge, RidgeCV
import gc
from catboost import CatBoostRegressor
import seaborn as sns
import warnings

from utils import freq_from_crossings, freq_from_fft

# %%
# %%time
train = pd.read_csv('../input/train.csv', dtype={'acoustic_data': np.int16, 'time_to_failure': np.float32})
fs = 4000000
# Out:
# CPU times: user 1min 18s, sys: 3.43 s, total: 1min 21s
# Wall time: 1min 21s

# %%
train.head()
# Out:
#    acoustic_data    time_to_failure
# 0             12  1.469099998474121
# 1              6  1.469099998474121
# 2              8  1.469099998474121
# 3              5  1.469099998474121
# 4              8  1.469099998474121

# %%
train.shape
# Out:
# (629145480, 2)

# %%
train_acoustic_data_small = train['acoustic_data'].values[::50]
train_time_to_failure_small = train['time_to_failure'].values[::50]

fig, ax1 = plt.subplots(figsize=(16, 8))
plt.title("Trends of acoustic_data and time_to_failure. 2% of data (sampled)")
plt.plot(train_acoustic_data_small, color='b')
ax1.set_ylabel('acoustic_data', color='b')
plt.legend(['acoustic_data'])
ax2 = ax1.twinx()
plt.plot(train_time_to_failure_small, color='g')
ax2.set_ylabel('time_to_failure', color='g')
plt.legend(['time_to_failure'], loc=(0.875, 0.9))
plt.grid(False)

del train_acoustic_data_small
del train_time_to_failure_small

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))
plt.title("Trends of acoustic_data and time_to_failure. First 2% of data")
plt.plot(train['acoustic_data'].values[:12582910], color='b')
ax1.set_ylabel('acoustic_data', color='b')
plt.legend(['acoustic_data'])
ax2 = ax1.twinx()
plt.plot(train['time_to_failure'].values[:12582910], color='g')
ax2.set_ylabel('time_to_failure', color='g')
plt.legend(['time_to_failure'], loc=(0.875, 0.9))
plt.grid(False)

# %%
# Create a training file with simple derived features
# TODO: Shall we split also the earthquackes?
# TODO: Where is the division by zero?
rows = 150_000
segments = int(np.floor(train.shape[0] / rows))

X_tr = pd.DataFrame(index=range(segments), dtype=np.float64,
                       columns=['ave', 'std', 'max', 'min',
                               'av_change_abs', 'av_change_rate', 'abs_max', 'abs_min',
                               'std_first_50000', 'std_last_50000', 'std_first_10000', 'std_last_10000',
                               'avg_first_50000', 'avg_last_50000', 'avg_first_10000', 'avg_last_10000',
                               'min_first_50000', 'min_last_50000', 'min_first_10000', 'min_last_10000',
                               'max_first_50000', 'max_last_50000', 'max_first_10000', 'max_last_10000',
                               'freq_cross_first_50000', 'freq_cross_last_50000', 'freq_cross_first_10000', 'freq_cross_last_10000'])
y_tr = pd.DataFrame(index=range(segments), dtype=np.float64,
                       columns=['time_to_failure'])

total_mean = train['acoustic_data'].mean()
total_std = train['acoustic_data'].std()
total_max = train['acoustic_data'].max()
total_min = train['acoustic_data'].min()
total_sum = train['acoustic_data'].sum()
total_abs_max = np.abs(train['acoustic_data']).sum()

for segment in tqdm_notebook(range(segments)):
    seg = train.iloc[segment*rows:segment*rows+rows]
    x = seg['acoustic_data'].values
    y = seg['time_to_failure'].values[-1]
    
    y_tr.loc[segment, 'time_to_failure'] = y
    X_tr.loc[segment, 'ave'] = x.mean()
    X_tr.loc[segment, 'std'] = x.std()
    X_tr.loc[segment, 'max'] = x.max()
    X_tr.loc[segment, 'min'] = x.min()
    
    X_tr.loc[segment, 'av_change_abs'] = np.mean(np.diff(x))
    X_tr.loc[segment, 'av_change_rate'] = np.mean(np.nonzero((np.diff(x) / x[:-1]))[0])
    X_tr.loc[segment, 'abs_max'] = np.abs(x).max()
    X_tr.loc[segment, 'abs_min'] = np.abs(x).min()
    
    X_tr.loc[segment, 'std_first_50000'] = x[:50000].std()
    X_tr.loc[segment, 'std_last_50000'] = x[-50000:].std()
    X_tr.loc[segment, 'std_first_10000'] = x[:10000].std()
    X_tr.loc[segment, 'std_last_10000'] = x[-10000:].std()
    
    X_tr.loc[segment, 'avg_first_50000'] = x[:50000].mean()
    X_tr.loc[segment, 'avg_last_50000'] = x[-50000:].mean()
    X_tr.loc[segment, 'avg_first_10000'] = x[:10000].mean()
    X_tr.loc[segment, 'avg_last_10000'] = x[-10000:].mean()
    
    X_tr.loc[segment, 'min_first_50000'] = x[:50000].min()
    X_tr.loc[segment, 'min_last_50000'] = x[-50000:].min()
    X_tr.loc[segment, 'min_first_10000'] = x[:10000].min()
    X_tr.loc[segment, 'min_last_10000'] = x[-10000:].min()
    
    X_tr.loc[segment, 'max_first_50000'] = x[:50000].max()
    X_tr.loc[segment, 'max_last_50000'] = x[-50000:].max()
    X_tr.loc[segment, 'max_first_10000'] = x[:10000].max()
    X_tr.loc[segment, 'max_last_10000'] = x[-10000:].max()
    
    X_tr.loc[segment, 'freq_cross_first_50000'] = freq_from_crossings(x[:50000], fs)
    X_tr.loc[segment, 'freq_cross_last_50000'] = freq_from_crossings(x[-50000:], fs)
    X_tr.loc[segment, 'freq_cross_first_10000'] = freq_from_crossings(x[:10000], fs)
    X_tr.loc[segment, 'freq_cross_last_10000'] = freq_from_crossings(x[-10000:], fs)
# Out:
# HBox(children=(IntProgress(value=0, max=4194), HTML(value='')))
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: RuntimeWarning: divide by zero encountered in true_divide
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:37: RuntimeWarning: invalid value encountered in true_divide

# %%
print(f'{X_tr.shape[0]} samples in new train data.')
# Out:
# 4194 samples in new train data.

# %%
X_tr.columns.size
# Out:
# 28

# %%
plt.figure(figsize=(26, 24))
for i, col in enumerate(X_tr.columns):
    plt.subplot(8, 4, i + 1)
    plt.plot(X_tr[col], color='blue')
    plt.title(col)
    ax1.set_ylabel(col, color='b')
    # plt.legend([col])
    ax2 = ax1.twinx()
    plt.plot(y_tr, color='g')
    ax2.set_ylabel('time_to_failure', color='g')
    plt.legend([col, 'time_to_failure'], loc=(0.875, 0.9))
    plt.grid(False)

# %%
scaler = StandardScaler()
scaler.fit(X_tr)
X_train_scaled = pd.DataFrame(scaler.transform(X_tr), columns=X_tr.columns)

# %%
submission = pd.read_csv('../input/sample_submission.csv', index_col='seg_id')
X_test = pd.DataFrame(columns=X_tr.columns, dtype=np.float64, index=submission.index)
plt.figure(figsize=(22, 16))

for i, seg_id in enumerate(tqdm_notebook(X_test.index)):
    seg = pd.read_csv('../input/test/' + seg_id + '.csv')
    
    x = seg['acoustic_data'].values
    X_test.loc[seg_id, 'ave'] = x.mean()
    X_test.loc[seg_id, 'std'] = x.std()
    X_test.loc[seg_id, 'max'] = x.max()
    X_test.loc[seg_id, 'min'] = x.min()
        
    X_test.loc[seg_id, 'av_change_abs'] = np.mean(np.diff(x))
    X_test.loc[seg_id, 'av_change_rate'] = np.mean(np.nonzero((np.diff(x) / x[:-1]))[0])
    X_test.loc[seg_id, 'abs_max'] = np.abs(x).max()
    X_test.loc[seg_id, 'abs_min'] = np.abs(x).min()
    
    X_test.loc[seg_id, 'std_first_50000'] = x[:50000].std()
    X_test.loc[seg_id, 'std_last_50000'] = x[-50000:].std()
    X_test.loc[seg_id, 'std_first_10000'] = x[:10000].std()
    X_test.loc[seg_id, 'std_last_10000'] = x[-10000:].std()
    
    X_test.loc[seg_id, 'avg_first_50000'] = x[:50000].mean()
    X_test.loc[seg_id, 'avg_last_50000'] = x[-50000:].mean()
    X_test.loc[seg_id, 'avg_first_10000'] = x[:10000].mean()
    X_test.loc[seg_id, 'avg_last_10000'] = x[-10000:].mean()
    
    X_test.loc[seg_id, 'min_first_50000'] = x[:50000].min()
    X_test.loc[seg_id, 'min_last_50000'] = x[-50000:].min()
    X_test.loc[seg_id, 'min_first_10000'] = x[:10000].min()
    X_test.loc[seg_id, 'min_last_10000'] = x[-10000:].min()
    
    X_test.loc[seg_id, 'max_first_50000'] = x[:50000].max()
    X_test.loc[seg_id, 'max_last_50000'] = x[-50000:].max()
    X_test.loc[seg_id, 'max_first_10000'] = x[:10000].max()
    X_test.loc[seg_id, 'max_last_10000'] = x[-10000:].max()
    
    X_test.loc[seg_id, 'freq_cross_first_50000'] = freq_from_crossings(x[:50000], fs)
    X_test.loc[seg_id, 'freq_cross_last_50000'] = freq_from_crossings(x[-50000:], fs)
    X_test.loc[seg_id, 'freq_cross_first_10000'] = freq_from_crossings(x[:10000], fs)
    X_test.loc[seg_id, 'freq_cross_last_10000'] = freq_from_crossings(x[-10000:], fs)
    
    if i < 24:
        plt.subplot(7, 4, i + 1)
        plt.plot(seg['acoustic_data'])
        plt.title(seg_id)
# Out:
# HBox(children=(IntProgress(value=0, max=2624), HTML(value='')))
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: divide by zero encountered in true_divide
#   from ipykernel import kernelapp as app
# /usr/local/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in true_divide
#   from ipykernel import kernelapp as app

# %%
X_tr.head()
# Out:
#                  ave                std    max    min      av_change_abs  \
# 0  4.884113333333334  5.101089126891323  104.0  -98.0 -0.000080000533337
# 1  4.725766666666667  6.588801819164257  181.0 -154.0  0.000000000000000
# 2  4.906393333333333  6.967373808828945  140.0 -106.0 -0.000013333422223
# 3  4.902240000000000  6.922282112791032  197.0 -199.0  0.000000000000000
# 4  4.908720000000000  7.301085852684289  145.0 -126.0 -0.000006666711111
#
#           av_change_rate  abs_max  abs_min    std_first_50000  \
# 0  74836.577199220613693    104.0      0.0  6.488487003146419
# 1  74891.736231905975728    181.0      0.0  7.305159645072789
# 2  75099.224450501744286    140.0      0.0  6.104775408645269
# 3  74933.991878648565034    199.0      0.0  6.238047094275579
# 4  75010.016045975266024    145.0      0.0  5.323776277643530
#
#       std_last_50000           ...            min_first_10000  min_last_10000  \
# 0  3.664626773410902           ...                      -98.0           -16.0
# 1  5.493015569284325           ...                      -23.0           -24.0
# 2  8.603609576427791           ...                      -87.0           -71.0
# 3  5.652385375078384           ...                      -48.0           -36.0
# 4  7.694429122189637           ...                      -44.0          -126.0
#
#    max_first_50000  max_last_50000  max_first_10000  max_last_10000  \
# 0            104.0            30.0            104.0            26.0
# 1            181.0           111.0             29.0            29.0
# 2             97.0           140.0             97.0            95.0
# 3             75.0            84.0             75.0            35.0
# 4             93.0           128.0             57.0           128.0
#
#    freq_cross_first_50000   freq_cross_last_50000  freq_cross_first_10000  \
# 0  235294.117647058825241  222222.222222222218988  231386.035526430147002
# 1  234817.247885952820070  222664.015904611209407  213333.333333333343035
# 2  231884.057971014495706  226567.768037766858470  240000.000000008731149
# 3  235294.117647058825241  223880.597014901053626  230769.230769234796753
# 4  215053.763440866518067  208695.652173939452041  210526.315789473679615
#
#     freq_cross_last_10000
# 0  240963.855421688058414
# 1  211161.387631976744160
# 2  241206.030150751554174
# 3  206388.206388207298005
# 4  231884.057971014495706
#
# [5 rows x 28 columns]

# %%
X_test.head()
# Out:
#                           ave                std    max    min  \
# seg_id
# seg_00030f  4.491780000000000  4.893673374701939  115.0  -75.0
# seg_0012b5  4.171153333333334  5.922819700375451  152.0 -140.0
# seg_00184e  4.610260000000000  6.946966920827151  248.0 -193.0
# seg_003339  4.531473333333333  4.114132889113924   85.0  -93.0
# seg_0042cc  4.128340000000000  5.797144312308719  177.0 -147.0
#
#                 av_change_abs         av_change_rate  abs_max  abs_min  \
# seg_id
# seg_00030f  0.000026666844446  75044.983541275520111    115.0      0.0
# seg_0012b5 -0.000013333422223  74949.685652956031845    152.0      0.0
# seg_00184e -0.000020000133334  74997.632054261513986    248.0      0.0
# seg_003339  0.000046666977780  74997.954642264914582     93.0      0.0
# seg_0042cc -0.000006666711111  75075.108146992672118    177.0      0.0
#
#               std_first_50000     std_last_50000           ...            \
# seg_id                                                     ...
# seg_00030f  5.350397529754215  4.793827681467076           ...
# seg_0012b5  6.249452857682823  4.147520836162249           ...
# seg_00184e  9.793375065195859  5.225861226630497           ...
# seg_003339  3.664051054447795  3.480805049352807           ...
# seg_0042cc  5.321079585948700  7.486067361599146           ...
#
#             min_first_10000  min_last_10000  max_first_50000  max_last_50000  \
# seg_id
# seg_00030f            -36.0           -37.0            115.0            43.0
# seg_0012b5            -12.0           -19.0            152.0            49.0
# seg_00184e            -26.0            -8.0            248.0            92.0
# seg_003339            -23.0            -7.0             51.0            72.0
# seg_0042cc            -37.0           -79.0             99.0           177.0
#
#             max_first_10000  max_last_10000  freq_cross_first_50000  \
# seg_id
# seg_00030f             45.0            43.0  237623.762376237893477
# seg_0012b5             22.0            40.0  260162.601626016257796
# seg_00184e             49.0            19.0  232791.769148161314661
# seg_003339             34.0            15.0  216110.019646370841656
# seg_0042cc             49.0            72.0  242005.185825416643638
#
#              freq_cross_last_50000  freq_cross_first_10000  \
# seg_id
# seg_00030f  244897.959183637110982  240240.240240245475434
# seg_0012b5  238984.316654229944106  265193.370165743166581
# seg_00184e  219703.574542276561260  234948.604992656590184
# seg_003339  189723.320158080954570  219378.427787942200666
# seg_0042cc  250434.782608689303743  250000.000000000000000
#
#              freq_cross_last_10000
# seg_id
# seg_00030f  265193.370165743166581
# seg_0012b5  246786.632390743179712
# seg_00184e  194331.983805670868605
# seg_003339  166956.521739130577771
# seg_0042cc  243902.439024388877442
#
# [5 rows x 28 columns]

# %%
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
n_fold = 5
folds = KFold(n_splits=n_fold, shuffle=True, random_state=11)

# %%
def train_model(X=X_train_scaled, X_test=X_test_scaled, y=y_tr, params=None, folds=folds, model_type='lgb', plot_feature_importance=False, model=None):

    oof = np.zeros(len(X))
    prediction = np.zeros(len(X_test))
    scores = []
    feature_importance = pd.DataFrame()
    for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
        print('Fold', fold_n, 'started at', time.ctime())
        X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
        y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
        
        if model_type == 'lgb':
            model = lgb.LGBMRegressor(**params, n_estimators = 20000, nthread = 4, n_jobs = -1)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric='mae',
                    verbose=10000, early_stopping_rounds=200)
            
            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test, num_iteration=model.best_iteration_)
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X_tr.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X_tr.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=20000, evals=watchlist, early_stopping_rounds=200, verbose_eval=500, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X_tr.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X_tr.columns), ntree_limit=model.best_ntree_limit)
            
        if model_type == 'rcv':
            model = RidgeCV(alphas=(0.01, 0.1, 1.0, 10.0, 100.0), scoring='neg_mean_absolute_error', cv=3)
            model.fit(X_train, y_train)
            print(model.alpha_)

            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = mean_absolute_error(y_valid, y_pred_valid)
            print(f'Fold {fold_n}. MAE: {score:.4f}.')
            print('')
            
            y_pred = model.predict(X_test).reshape(-1,)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train.values.ravel())
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = mean_absolute_error(y_valid, y_pred_valid)
            print(f'Fold {fold_n}. MAE: {score:.4f}.')
            print('')
            
            y_pred = model.predict(X_test).reshape(-1,)
        
        if model_type == 'cat':
            model = CatBoostRegressor(iterations=20000,  eval_metric='MAE', **params)
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose=False)

            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test)
        
        oof[valid_index] = y_pred_valid.reshape(-1,)
        scores.append(mean_absolute_error(y_valid, y_pred_valid))

        prediction += y_pred    
        
        if model_type == 'lgb':
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = X.columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_fold
    
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    if model_type == 'lgb':
        feature_importance["importance"] /= n_fold
        if plot_feature_importance:
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12));
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
            plt.title('LGB Features (avg over folds)');
        
            return oof, prediction, feature_importance
        return oof, prediction
    
    else:
        return oof, prediction

# %%
params = {'num_leaves': 54,
         'min_data_in_leaf': 79,
         'objective': 'huber',
         'max_depth': -1,
         'learning_rate': 0.01,
         "boosting": "gbdt",
         # "feature_fraction": 0.8354507676881442,
         "bagging_freq": 3,
         "bagging_fraction": 0.8126672064208567,
         "bagging_seed": 11,
         "metric": 'mae',
         "verbosity": -1,
         'reg_alpha': 1.1302650970728192,
         'reg_lambda': 0.3603427518866501
         }
oof_lgb, prediction_lgb, feature_importance = train_model(params=params, model_type='lgb', plot_feature_importance=True)
# Out:
# Fold 0 started at Fri Mar  1 22:45:52 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [896]	training's l1: 1.87813	valid_1's l1: 1.75907
# Fold 1 started at Fri Mar  1 22:45:54 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1845]	training's l1: 1.61177	valid_1's l1: 1.99328
# Fold 2 started at Fri Mar  1 22:45:58 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1260]	training's l1: 1.75685	valid_1's l1: 2.14637
# Fold 3 started at Fri Mar  1 22:46:00 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1221]	training's l1: 1.761	valid_1's l1: 2.58965
# Fold 4 started at Fri Mar  1 22:46:03 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1047]	training's l1: 1.81109	valid_1's l1: 2.61207
# Fold 5 started at Fri Mar  1 22:46:05 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [570]	training's l1: 2.01302	valid_1's l1: 2.39023
# Fold 6 started at Fri Mar  1 22:46:06 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1023]	training's l1: 1.83321	valid_1's l1: 1.86919
# Fold 7 started at Fri Mar  1 22:46:08 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [840]	training's l1: 1.88408	valid_1's l1: 2.35897
# Fold 8 started at Fri Mar  1 22:46:10 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1056]	training's l1: 1.82451	valid_1's l1: 2.02329
# Fold 9 started at Fri Mar  1 22:46:12 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1056]	training's l1: 1.82403	valid_1's l1: 1.85055
# Fold 10 started at Fri Mar  1 22:46:14 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1812]	training's l1: 1.61748	valid_1's l1: 2.14908
# Fold 11 started at Fri Mar  1 22:46:17 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [2262]	training's l1: 1.52154	valid_1's l1: 1.83684
# Fold 12 started at Fri Mar  1 22:46:22 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [3600]	training's l1: 1.266	valid_1's l1: 2.0443
# Fold 13 started at Fri Mar  1 22:46:29 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [903]	training's l1: 1.86973	valid_1's l1: 2.07443
# Fold 14 started at Fri Mar  1 22:46:31 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1167]	training's l1: 1.78164	valid_1's l1: 2.31251
# Fold 15 started at Fri Mar  1 22:46:33 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1725]	training's l1: 1.64281	valid_1's l1: 2.0516
# Fold 16 started at Fri Mar  1 22:46:36 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [606]	training's l1: 1.99367	valid_1's l1: 2.1078
# Fold 17 started at Fri Mar  1 22:46:37 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1245]	training's l1: 1.76754	valid_1's l1: 2.06784
# Fold 18 started at Fri Mar  1 22:46:40 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1236]	training's l1: 1.76248	valid_1's l1: 2.20137
# Fold 19 started at Fri Mar  1 22:46:42 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [846]	training's l1: 1.89084	valid_1's l1: 1.92295
# Fold 20 started at Fri Mar  1 22:46:44 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1475]	training's l1: 1.70012	valid_1's l1: 2.19959
# Fold 21 started at Fri Mar  1 22:46:47 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1686]	training's l1: 1.64535	valid_1's l1: 2.3072
# Fold 22 started at Fri Mar  1 22:46:50 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1089]	training's l1: 1.80481	valid_1's l1: 2.31817
# Fold 23 started at Fri Mar  1 22:46:52 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [759]	training's l1: 1.91837	valid_1's l1: 2.23967
# Fold 24 started at Fri Mar  1 22:46:54 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1362]	training's l1: 1.7252	valid_1's l1: 2.4952
# Fold 25 started at Fri Mar  1 22:46:57 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [561]	training's l1: 2.01992	valid_1's l1: 2.24368
# Fold 26 started at Fri Mar  1 22:46:58 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [666]	training's l1: 1.9645	valid_1's l1: 2.08209
# Fold 27 started at Fri Mar  1 22:46:59 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1158]	training's l1: 1.7871	valid_1's l1: 2.2736
# Fold 28 started at Fri Mar  1 22:47:02 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [986]	training's l1: 1.84161	valid_1's l1: 2.08491
# Fold 29 started at Fri Mar  1 22:47:04 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1659]	training's l1: 1.65971	valid_1's l1: 1.95703
# Fold 30 started at Fri Mar  1 22:47:07 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1785]	training's l1: 1.62874	valid_1's l1: 1.9561
# Fold 31 started at Fri Mar  1 22:47:10 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [729]	training's l1: 1.93506	valid_1's l1: 1.99184
# Fold 32 started at Fri Mar  1 22:47:12 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1326]	training's l1: 1.74275	valid_1's l1: 2.14996
# Fold 33 started at Fri Mar  1 22:47:14 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [621]	training's l1: 1.98407	valid_1's l1: 2.27529
# Fold 34 started at Fri Mar  1 22:47:16 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1275]	training's l1: 1.77011	valid_1's l1: 1.48815
# Fold 35 started at Fri Mar  1 22:47:18 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [804]	training's l1: 1.90681	valid_1's l1: 1.94517
# Fold 36 started at Fri Mar  1 22:47:20 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1044]	training's l1: 1.82888	valid_1's l1: 1.85276
# Fold 37 started at Fri Mar  1 22:47:22 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [918]	training's l1: 1.86887	valid_1's l1: 1.77437
# Fold 38 started at Fri Mar  1 22:47:24 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1446]	training's l1: 1.70806	valid_1's l1: 2.29954
# Fold 39 started at Fri Mar  1 22:47:27 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1026]	training's l1: 1.82984	valid_1's l1: 1.98246
# Fold 40 started at Fri Mar  1 22:47:29 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1554]	training's l1: 1.68772	valid_1's l1: 1.8773
# Fold 41 started at Fri Mar  1 22:47:32 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [3597]	training's l1: 1.26614	valid_1's l1: 2.08759
# Fold 42 started at Fri Mar  1 22:47:39 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1113]	training's l1: 1.80524	valid_1's l1: 1.83043
# Fold 43 started at Fri Mar  1 22:47:41 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [2774]	training's l1: 1.41413	valid_1's l1: 1.98615
# Fold 44 started at Fri Mar  1 22:47:46 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [953]	training's l1: 1.85287	valid_1's l1: 2.11519
# Fold 45 started at Fri Mar  1 22:47:48 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1206]	training's l1: 1.77476	valid_1's l1: 2.08323
# Fold 46 started at Fri Mar  1 22:47:51 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1617]	training's l1: 1.66579	valid_1's l1: 2.04923
# Fold 47 started at Fri Mar  1 22:47:54 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [700]	training's l1: 1.94687	valid_1's l1: 2.13985
# Fold 48 started at Fri Mar  1 22:47:55 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [1071]	training's l1: 1.81107	valid_1's l1: 2.36423
# Fold 49 started at Fri Mar  1 22:47:57 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [945]	training's l1: 1.85024	valid_1's l1: 2.24685
# CV mean score: 2.1012, std: 0.2161.

# %%
xgb_params = {'eta': 0.04, 'max_depth': 10, 'subsample': 0.9, #'colsample_bytree': 0.8, 
          'objective': 'reg:linear', 'eval_metric': 'mae', 'silent': True, 'nthread': 4}
oof_xgb, prediction_xgb = train_model(params=xgb_params, model_type='xgb')
# Out:
# Fold 0 started at Fri Mar  1 22:48:00 2019
# [0]	train-mae:5.0207	valid_data-mae:4.78169
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [71]	train-mae:0.864909	valid_data-mae:1.80973
#
# Fold 1 started at Fri Mar  1 22:48:02 2019
# [0]	train-mae:5.01545	valid_data-mae:5.12057
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [65]	train-mae:0.915746	valid_data-mae:2.09477
#
# Fold 2 started at Fri Mar  1 22:48:04 2019
# [0]	train-mae:5.01618	valid_data-mae:5.13253
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [186]	train-mae:0.361096	valid_data-mae:2.20112
#
# Fold 3 started at Fri Mar  1 22:48:07 2019
# [0]	train-mae:5.00038	valid_data-mae:5.8217
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [73]	train-mae:0.815435	valid_data-mae:2.62464
#
# Fold 4 started at Fri Mar  1 22:48:09 2019
# [0]	train-mae:4.99578	valid_data-mae:6.00942
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [144]	train-mae:0.468409	valid_data-mae:2.55515
#
# Fold 5 started at Fri Mar  1 22:48:11 2019
# [0]	train-mae:5.01437	valid_data-mae:5.08778
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [72]	train-mae:0.836523	valid_data-mae:2.36101
#
# Fold 6 started at Fri Mar  1 22:48:13 2019
# [0]	train-mae:5.03285	valid_data-mae:4.18256
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [42]	train-mae:1.3847	valid_data-mae:1.79737
#
# Fold 7 started at Fri Mar  1 22:48:15 2019
# [0]	train-mae:5.01422	valid_data-mae:5.10572
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# [500]	train-mae:0.046283	valid_data-mae:2.34677
# Stopping. Best iteration:
# [522]	train-mae:0.040041	valid_data-mae:2.34587
#
# Fold 8 started at Fri Mar  1 22:48:20 2019
# [0]	train-mae:5.00698	valid_data-mae:5.38707
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [90]	train-mae:0.687338	valid_data-mae:2.08019
#
# Fold 9 started at Fri Mar  1 22:48:22 2019
# [0]	train-mae:5.02305	valid_data-mae:4.70767
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [57]	train-mae:1.03044	valid_data-mae:1.93357
#
# Fold 10 started at Fri Mar  1 22:48:24 2019
# [0]	train-mae:5.02236	valid_data-mae:4.711
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [198]	train-mae:0.328901	valid_data-mae:2.17847
#
# Fold 11 started at Fri Mar  1 22:48:27 2019
# [0]	train-mae:5.00926	valid_data-mae:5.36042
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [83]	train-mae:0.748412	valid_data-mae:1.8759
#
# Fold 12 started at Fri Mar  1 22:48:29 2019
# [0]	train-mae:5.00957	valid_data-mae:5.39264
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [128]	train-mae:0.519066	valid_data-mae:2.11152
#
# Fold 13 started at Fri Mar  1 22:48:31 2019
# [0]	train-mae:5.02516	valid_data-mae:4.619
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [61]	train-mae:0.979751	valid_data-mae:2.04526
#
# Fold 14 started at Fri Mar  1 22:48:33 2019
# [0]	train-mae:5.01944	valid_data-mae:4.92322
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [126]	train-mae:0.530476	valid_data-mae:2.41719
#
# Fold 15 started at Fri Mar  1 22:48:35 2019
# [0]	train-mae:5.0069	valid_data-mae:5.43602
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [130]	train-mae:0.503603	valid_data-mae:2.04447
#
# Fold 16 started at Fri Mar  1 22:48:38 2019
# [0]	train-mae:5.01337	valid_data-mae:5.17091
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [77]	train-mae:0.797592	valid_data-mae:2.14093
#
# Fold 17 started at Fri Mar  1 22:48:40 2019
# [0]	train-mae:5.00922	valid_data-mae:5.37677
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [93]	train-mae:0.683306	valid_data-mae:2.23142
#
# Fold 18 started at Fri Mar  1 22:48:42 2019
# [0]	train-mae:5.03022	valid_data-mae:4.43025
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [68]	train-mae:0.884475	valid_data-mae:2.23509
#
# Fold 19 started at Fri Mar  1 22:48:44 2019
# [0]	train-mae:5.01856	valid_data-mae:4.88726
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [67]	train-mae:0.888793	valid_data-mae:2.12464
#
# Fold 20 started at Fri Mar  1 22:48:46 2019
# [0]	train-mae:5.01159	valid_data-mae:5.30953
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [108]	train-mae:0.579573	valid_data-mae:2.26384
#
# Fold 21 started at Fri Mar  1 22:48:48 2019
# [0]	train-mae:5.00911	valid_data-mae:5.31497
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [69]	train-mae:0.85822	valid_data-mae:2.43598
#
# Fold 22 started at Fri Mar  1 22:48:50 2019
# [0]	train-mae:5.01255	valid_data-mae:5.20807
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [107]	train-mae:0.604445	valid_data-mae:2.35683
#
# Fold 23 started at Fri Mar  1 22:48:52 2019
# [0]	train-mae:5.02438	valid_data-mae:4.61339
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [48]	train-mae:1.20798	valid_data-mae:2.31751
#
# Fold 24 started at Fri Mar  1 22:48:54 2019
# [0]	train-mae:5.00882	valid_data-mae:5.55686
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# [500]	train-mae:0.044631	valid_data-mae:2.62069
# Stopping. Best iteration:
# [350]	train-mae:0.11393	valid_data-mae:2.61754
#
# Fold 25 started at Fri Mar  1 22:48:58 2019
# [0]	train-mae:5.02082	valid_data-mae:4.75933
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [58]	train-mae:1.02065	valid_data-mae:2.27512
#
# Fold 26 started at Fri Mar  1 22:49:00 2019
# [0]	train-mae:5.01777	valid_data-mae:4.9588
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [72]	train-mae:0.8286	valid_data-mae:2.10793
#
# Fold 27 started at Fri Mar  1 22:49:02 2019
# [0]	train-mae:5.01916	valid_data-mae:4.86587
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [100]	train-mae:0.633773	valid_data-mae:2.30284
#
# Fold 28 started at Fri Mar  1 22:49:04 2019
# [0]	train-mae:5.02166	valid_data-mae:4.88342
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [132]	train-mae:0.513786	valid_data-mae:2.16664
#
# Fold 29 started at Fri Mar  1 22:49:07 2019
# [0]	train-mae:5.01037	valid_data-mae:5.25372
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [108]	train-mae:0.588612	valid_data-mae:2.0808
#
# Fold 30 started at Fri Mar  1 22:49:09 2019
# [0]	train-mae:5.01708	valid_data-mae:5.04359
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [112]	train-mae:0.575464	valid_data-mae:2.0472
#
# Fold 31 started at Fri Mar  1 22:49:11 2019
# [0]	train-mae:5.00788	valid_data-mae:5.41217
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [112]	train-mae:0.575504	valid_data-mae:2.13182
#
# Fold 32 started at Fri Mar  1 22:49:13 2019
# [0]	train-mae:5.01907	valid_data-mae:4.84952
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [121]	train-mae:0.530724	valid_data-mae:2.07858
#
# Fold 33 started at Fri Mar  1 22:49:16 2019
# [0]	train-mae:5.01308	valid_data-mae:5.13341
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [99]	train-mae:0.630443	valid_data-mae:2.31643
#
# Fold 34 started at Fri Mar  1 22:49:18 2019
# [0]	train-mae:5.02755	valid_data-mae:4.42484
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [57]	train-mae:1.03919	valid_data-mae:1.52478
#
# Fold 35 started at Fri Mar  1 22:49:20 2019
# [0]	train-mae:5.02867	valid_data-mae:4.3465
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [48]	train-mae:1.22245	valid_data-mae:2.05751
#
# Fold 36 started at Fri Mar  1 22:49:21 2019
# [0]	train-mae:5.01853	valid_data-mae:4.82467
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [98]	train-mae:0.632421	valid_data-mae:1.89716
#
# Fold 37 started at Fri Mar  1 22:49:23 2019
# [0]	train-mae:5.02125	valid_data-mae:4.66276
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [56]	train-mae:1.04817	valid_data-mae:1.94512
#
# Fold 38 started at Fri Mar  1 22:49:25 2019
# [0]	train-mae:5.02592	valid_data-mae:4.5002
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# [500]	train-mae:0.05306	valid_data-mae:2.22721
# Stopping. Best iteration:
# [369]	train-mae:0.116655	valid_data-mae:2.22269
#
# Fold 39 started at Fri Mar  1 22:49:29 2019
# [0]	train-mae:5.01255	valid_data-mae:5.31068
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [71]	train-mae:0.849615	valid_data-mae:2.08401
#
# Fold 40 started at Fri Mar  1 22:49:31 2019
# [0]	train-mae:5.02594	valid_data-mae:4.47898
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [82]	train-mae:0.744738	valid_data-mae:1.96552
#
# Fold 41 started at Fri Mar  1 22:49:33 2019
# [0]	train-mae:5.00898	valid_data-mae:5.40861
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# [500]	train-mae:0.053845	valid_data-mae:2.0696
# Stopping. Best iteration:
# [431]	train-mae:0.080692	valid_data-mae:2.06833
#
# Fold 42 started at Fri Mar  1 22:49:38 2019
# [0]	train-mae:5.03085	valid_data-mae:4.28374
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [52]	train-mae:1.12823	valid_data-mae:1.96551
#
# Fold 43 started at Fri Mar  1 22:49:40 2019
# [0]	train-mae:5.01793	valid_data-mae:5.03707
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# [500]	train-mae:0.049047	valid_data-mae:2.08503
# Stopping. Best iteration:
# [509]	train-mae:0.047035	valid_data-mae:2.08453
#
# Fold 44 started at Fri Mar  1 22:49:45 2019
# [0]	train-mae:5.01391	valid_data-mae:5.06288
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [51]	train-mae:1.15132	valid_data-mae:2.18667
#
# Fold 45 started at Fri Mar  1 22:49:47 2019
# [0]	train-mae:5.01785	valid_data-mae:4.96908
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [87]	train-mae:0.69584	valid_data-mae:2.12389
#
# Fold 46 started at Fri Mar  1 22:49:49 2019
# [0]	train-mae:5.01888	valid_data-mae:4.92637
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [60]	train-mae:0.997411	valid_data-mae:2.03969
#
# Fold 47 started at Fri Mar  1 22:49:50 2019
# [0]	train-mae:5.01256	valid_data-mae:5.26114
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [96]	train-mae:0.653158	valid_data-mae:2.28439
#
# Fold 48 started at Fri Mar  1 22:49:53 2019
# [0]	train-mae:5.01052	valid_data-mae:5.2721
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# Stopping. Best iteration:
# [84]	train-mae:0.734472	valid_data-mae:2.29556
#
# Fold 49 started at Fri Mar  1 22:49:55 2019
# [0]	train-mae:5.00255	valid_data-mae:5.77392
# Multiple eval metrics have been passed: 'valid_data-mae' will be used for early stopping.
#
# Will train until valid_data-mae hasn't improved in 200 rounds.
# [500]	train-mae:0.050278	valid_data-mae:2.17805
# Stopping. Best iteration:
# [327]	train-mae:0.141829	valid_data-mae:2.1771
#
# CV mean score: 2.1526, std: 0.2038.

# %%
model = NuSVR(gamma='scale', nu=0.7, C=10.0)
oof_svr, prediction_svr = train_model(params=None, model_type='sklearn', model=model)
# Out:
# Fold 0 started at Fri Mar  1 22:49:58 2019
# Fold 0. MAE: 1.8406.
#
# Fold 1 started at Fri Mar  1 22:50:00 2019
# Fold 1. MAE: 1.9242.
#
# Fold 2 started at Fri Mar  1 22:50:01 2019
# Fold 2. MAE: 2.1602.
#
# Fold 3 started at Fri Mar  1 22:50:02 2019
# Fold 3. MAE: 2.4482.
#
# Fold 4 started at Fri Mar  1 22:50:03 2019
# Fold 4. MAE: 2.5073.
#
# Fold 5 started at Fri Mar  1 22:50:04 2019
# Fold 5. MAE: 2.3580.
#
# Fold 6 started at Fri Mar  1 22:50:05 2019
# Fold 6. MAE: 1.9618.
#
# Fold 7 started at Fri Mar  1 22:50:06 2019
# Fold 7. MAE: 2.4123.
#
# Fold 8 started at Fri Mar  1 22:50:07 2019
# Fold 8. MAE: 2.0876.
#
# Fold 9 started at Fri Mar  1 22:50:08 2019
# Fold 9. MAE: 1.9438.
#
# Fold 10 started at Fri Mar  1 22:50:09 2019
# Fold 10. MAE: 2.0807.
#
# Fold 11 started at Fri Mar  1 22:50:10 2019
# Fold 11. MAE: 2.0239.
#
# Fold 12 started at Fri Mar  1 22:50:11 2019
# Fold 12. MAE: 2.0610.
#
# Fold 13 started at Fri Mar  1 22:50:12 2019
# Fold 13. MAE: 2.1726.
#
# Fold 14 started at Fri Mar  1 22:50:13 2019
# Fold 14. MAE: 2.3344.
#
# Fold 15 started at Fri Mar  1 22:50:14 2019
# Fold 15. MAE: 1.9576.
#
# Fold 16 started at Fri Mar  1 22:50:15 2019
# Fold 16. MAE: 2.1926.
#
# Fold 17 started at Fri Mar  1 22:50:16 2019
# Fold 17. MAE: 2.1129.
#
# Fold 18 started at Fri Mar  1 22:50:17 2019
# Fold 18. MAE: 2.2206.
#
# Fold 19 started at Fri Mar  1 22:50:18 2019
# Fold 19. MAE: 1.9875.
#
# Fold 20 started at Fri Mar  1 22:50:19 2019
# Fold 20. MAE: 2.1647.
#
# Fold 21 started at Fri Mar  1 22:50:20 2019
# Fold 21. MAE: 2.3948.
#
# Fold 22 started at Fri Mar  1 22:50:21 2019
# Fold 22. MAE: 2.3141.
#
# Fold 23 started at Fri Mar  1 22:50:22 2019
# Fold 23. MAE: 2.2121.
#
# Fold 24 started at Fri Mar  1 22:50:23 2019
# Fold 24. MAE: 2.5092.
#
# Fold 25 started at Fri Mar  1 22:50:24 2019
# Fold 25. MAE: 2.2782.
#
# Fold 26 started at Fri Mar  1 22:50:25 2019
# Fold 26. MAE: 2.0421.
#
# Fold 27 started at Fri Mar  1 22:50:26 2019
# Fold 27. MAE: 2.2736.
#
# Fold 28 started at Fri Mar  1 22:50:27 2019
# Fold 28. MAE: 2.1005.
#
# Fold 29 started at Fri Mar  1 22:50:28 2019
# Fold 29. MAE: 2.0517.
#
# Fold 30 started at Fri Mar  1 22:50:29 2019
# Fold 30. MAE: 2.0012.
#
# Fold 31 started at Fri Mar  1 22:50:30 2019
# Fold 31. MAE: 2.1236.
#
# Fold 32 started at Fri Mar  1 22:50:31 2019
# Fold 32. MAE: 2.1211.
#
# Fold 33 started at Fri Mar  1 22:50:32 2019
# Fold 33. MAE: 2.2528.
#
# Fold 34 started at Fri Mar  1 22:50:33 2019
# Fold 34. MAE: 1.4556.
#
# Fold 35 started at Fri Mar  1 22:50:34 2019
# Fold 35. MAE: 2.0137.
#
# Fold 36 started at Fri Mar  1 22:50:35 2019
# Fold 36. MAE: 1.9457.
#
# Fold 37 started at Fri Mar  1 22:50:36 2019
# Fold 37. MAE: 1.8868.
#
# Fold 38 started at Fri Mar  1 22:50:37 2019
# Fold 38. MAE: 2.2052.
#
# Fold 39 started at Fri Mar  1 22:50:38 2019
# Fold 39. MAE: 1.9079.
#
# Fold 40 started at Fri Mar  1 22:50:39 2019
# Fold 40. MAE: 1.9847.
#
# Fold 41 started at Fri Mar  1 22:50:40 2019
# Fold 41. MAE: 2.0883.
#
# Fold 42 started at Fri Mar  1 22:50:41 2019
# Fold 42. MAE: 1.8910.
#
# Fold 43 started at Fri Mar  1 22:50:42 2019
# Fold 43. MAE: 2.1740.
#
# Fold 44 started at Fri Mar  1 22:50:43 2019
# Fold 44. MAE: 2.1802.
#
# Fold 45 started at Fri Mar  1 22:50:45 2019
# Fold 45. MAE: 2.1231.
#
# Fold 46 started at Fri Mar  1 22:50:46 2019
# Fold 46. MAE: 2.1433.
#
# Fold 47 started at Fri Mar  1 22:50:47 2019
# Fold 47. MAE: 2.1268.
#
# Fold 48 started at Fri Mar  1 22:50:48 2019
# Fold 48. MAE: 2.4391.
#
# Fold 49 started at Fri Mar  1 22:50:49 2019
# Fold 49. MAE: 2.3618.
#
# CV mean score: 2.1311, std: 0.1943.

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_tr, color='g', label='y_train')
plt.plot(oof_lgb, color='b', label='lgb')
plt.plot(oof_xgb, color='teal', label='xgb')
plt.plot(oof_svr, color='red', label='svr')
plt.plot((oof_lgb + oof_xgb + oof_svr) / 3, color='gold', label='blend')
plt.legend();
plt.title('Predictions vs actual');

# %%
plt.figure(figsize=(16, 8))
plt.plot(prediction_lgb, color='b', label='lgb')
plt.plot(prediction_xgb, color='teal', label='xgb')
plt.plot(prediction_svr, color='red', label='svr')
plt.plot((prediction_lgb + prediction_xgb + prediction_svr) / 3, color='gold', label='blend')
plt.legend();
plt.title('Predictions vs actual');

# %%
submission['time_to_failure'] = (prediction_lgb + prediction_xgb + prediction_svr) / 3

# %%
submission.to_csv('../output/submission_rdg.csv')
