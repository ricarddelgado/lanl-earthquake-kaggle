# %% [markdown]
# ## General information
#
# In this kernel I'll try various technics for models interpretability and feature selection. Also I'll compare various models.
#
# I use the features from my dataset: https://www.kaggle.com/artgor/lanl-features
#
# This dataset was created using this kernel: https://www.kaggle.com/artgor/even-more-features/
#
# *work in progress*
#
# ![](https://torontoseoulcialite.com/wp-content/uploads/2016/02/zimbiocom.jpg)

# %%
import numpy as np
import pandas as pd
import os

import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from sklearn.svm import NuSVR, SVR
from sklearn.metrics import mean_absolute_error
pd.options.display.precision = 15
from sklearn.model_selection import train_test_split, KFold, cross_val_score, StratifiedKFold, GridSearchCV
from sklearn import svm
import lightgbm as lgb
import xgboost as xgb
import time
import datetime
from catboost import CatBoostRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn import neighbors
from sklearn.metrics import mean_absolute_error
from sklearn import linear_model
import gc
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.ensemble import ExtraTreesRegressor

from scipy.signal import hilbert
from scipy.signal import hann
from scipy.signal import convolve
from scipy import stats
from sklearn.kernel_ridge import KernelRidge
from sklearn.neighbors import NearestNeighbors
import librosa, librosa.display
import builtins
from sklearn.ensemble import RandomForestRegressor
import eli5
import shap
from sklearn.feature_selection import GenericUnivariateSelect, SelectPercentile, SelectKBest, f_classif, mutual_info_classif, RFE

# %% [markdown]
# importing and setting up altair

# %%
import altair as alt
from  altair.vega import v3
from IPython.display import HTML
import json
# Preparing altair. I use code from this great kernel: https://www.kaggle.com/notslush/altair-visualization-2018-stackoverflow-survey

vega_url = 'https://cdn.jsdelivr.net/npm/vega@' + v3.SCHEMA_VERSION
vega_lib_url = 'https://cdn.jsdelivr.net/npm/vega-lib'
vega_lite_url = 'https://cdn.jsdelivr.net/npm/vega-lite@' + alt.SCHEMA_VERSION
vega_embed_url = 'https://cdn.jsdelivr.net/npm/vega-embed@3'
noext = "?noext"

paths = {
    'vega': vega_url + noext,
    'vega-lib': vega_lib_url + noext,
    'vega-lite': vega_lite_url + noext,
    'vega-embed': vega_embed_url + noext
}

workaround = """
requirejs.config({{
    baseUrl: 'https://cdn.jsdelivr.net/npm/',
    paths: {}
}});
"""

#------------------------------------------------ Defs for future rendering
def add_autoincrement(render_func):
    # Keep track of unique <div/> IDs
    cache = {}
    def wrapped(chart, id="vega-chart", autoincrement=True):
        if autoincrement:
            if id in cache:
                counter = 1 + cache[id]
                cache[id] = counter
            else:
                cache[id] = 0
            actual_id = id if cache[id] == 0 else id + '-' + str(cache[id])
        else:
            if id not in cache:
                cache[id] = 0
            actual_id = id
        return render_func(chart, id=actual_id)
    # Cache will stay outside and 
    return wrapped
            
@add_autoincrement
def render(chart, id="vega-chart"):
    chart_str = """
    <div id="{id}"></div><script>
    require(["vega-embed"], function(vg_embed) {{
        const spec = {chart};     
        vg_embed("#{id}", spec, {{defaultStyle: true}}).catch(console.warn);
        console.log("anything?");
    }});
    console.log("really...anything?");
    </script>
    """
    return HTML(
        chart_str.format(
            id=id,
            chart=json.dumps(chart) if isinstance(chart, dict) else chart.to_json(indent=None)
        )
    )

HTML("".join((
    "<script>",
    workaround.format(json.dumps(paths)),
    "</script>",
)))
# Out:
# <script>
# requirejs.config({
#     baseUrl: 'https://cdn.jsdelivr.net/npm/',
#     paths: {"vega": "https://cdn.jsdelivr.net/npm/vega@v3.3.1?noext", "vega-lib": "https://cdn.jsdelivr.net/npm/vega-lib?noext", "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@v3.2.1?noext", "vega-embed": "https://cdn.jsdelivr.net/npm/vega-embed@3?noext"}
# });
# </script>

# %%
os.listdir('../input/lanl-features')
# Out:
# ['test_features_denoised.csv',
#  'train_features.csv',
#  'test_features.csv',
#  'submission_1.csv',
#  'y.csv',
#  'train_features_denoised.csv']

# %% [markdown]
# * 'train_features.csv' - train features generated on original data
# * 'train_features_denoised.csv' - train features generated on denoised data
# * 'test_features.csv' - test features generated on original data
# * 'test_features_denoised.csv' - test features generated on denoised data
# * 'submission_1.csv' - one of my local submissions
# * 'y.csv' - train target

# %% [markdown]
# ## Loading data
# Let's load features!

# %%
train_features = pd.read_csv('../input/lanl-features/train_features.csv')
test_features = pd.read_csv('../input/lanl-features/test_features.csv')
train_features_denoised = pd.read_csv('../input/lanl-features/train_features_denoised.csv')
test_features_denoised = pd.read_csv('../input/lanl-features/test_features_denoised.csv')
train_features_denoised.columns = [f'{i}_denoised' for i in train_features_denoised.columns]
test_features_denoised.columns = [f'{i}_denoised' for i in test_features_denoised.columns]
y = pd.read_csv('../input/lanl-features/y.csv')

# %%
X = pd.concat([train_features, train_features_denoised], axis=1).drop(['seg_id_denoised', 'target_denoised'], axis=1)
X_test = pd.concat([test_features, test_features_denoised], axis=1).drop(['seg_id_denoised', 'target_denoised'], axis=1)
X = X[:-1]
y = y[:-1]

# %% [markdown]
# We have almost 2000 features here!

# %%
n_fold = 5
folds = KFold(n_splits=n_fold, shuffle=True, random_state=11)

# %% [markdown]
# ## Training function
#
# Training function is in the hidden cell below

# %%
def train_model(X, X_test, y, params, folds, model_type='lgb', plot_feature_importance=False, model=None):

    oof = np.zeros(len(X))
    prediction = np.zeros(len(X_test))
    scores = []
    feature_importance = pd.DataFrame()
    for fold_n, (train_index, valid_index) in enumerate(folds.split(X)):
        print('Fold', fold_n, 'started at', time.ctime())
        if type(X) == np.ndarray:
            X_train, X_valid = X[train_index], X[valid_index]
            y_train, y_valid = y[train_index], y[valid_index]
        else:
            X_train, X_valid = X.iloc[train_index], X.iloc[valid_index]
            y_train, y_valid = y.iloc[train_index], y.iloc[valid_index]
            
        
        if model_type == 'lgb':
            model = lgb.LGBMRegressor(**params, n_estimators = 50000, n_jobs = -1)
            model.fit(X_train, y_train, 
                    eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric='mae',
                    verbose=10000, early_stopping_rounds=200)
            
            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test, num_iteration=model.best_iteration_)
            
        if model_type == 'xgb':
            train_data = xgb.DMatrix(data=X_train, label=y_train, feature_names=X.columns)
            valid_data = xgb.DMatrix(data=X_valid, label=y_valid, feature_names=X.columns)

            watchlist = [(train_data, 'train'), (valid_data, 'valid_data')]
            model = xgb.train(dtrain=train_data, num_boost_round=20000, evals=watchlist, early_stopping_rounds=200, verbose_eval=500, params=params)
            y_pred_valid = model.predict(xgb.DMatrix(X_valid, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
            y_pred = model.predict(xgb.DMatrix(X_test, feature_names=X.columns), ntree_limit=model.best_ntree_limit)
        
        if model_type == 'sklearn':
            model = model
            model.fit(X_train, y_train)
            
            y_pred_valid = model.predict(X_valid).reshape(-1,)
            score = mean_absolute_error(y_valid, y_pred_valid)
            print(f'Fold {fold_n}. MAE: {score:.4f}.')
            print('')
            
            y_pred = model.predict(X_test).reshape(-1,)
        
        if model_type == 'cat':
            model = CatBoostRegressor(iterations=20000,  eval_metric='MAE', **params, loss_function='MAE')
            model.fit(X_train, y_train, eval_set=(X_valid, y_valid), cat_features=[], use_best_model=True, verbose=False)

            y_pred_valid = model.predict(X_valid)
            y_pred = model.predict(X_test)
        
        oof[valid_index] = y_pred_valid.reshape(-1,)
        scores.append(mean_absolute_error(y_valid, y_pred_valid))

        prediction += y_pred    
        
        if model_type == 'lgb' and plot_feature_importance:
            # feature importance
            fold_importance = pd.DataFrame()
            fold_importance["feature"] = X.columns
            fold_importance["importance"] = model.feature_importances_
            fold_importance["fold"] = fold_n + 1
            feature_importance = pd.concat([feature_importance, fold_importance], axis=0)

    prediction /= n_fold
    
    print('CV mean score: {0:.4f}, std: {1:.4f}.'.format(np.mean(scores), np.std(scores)))
    
    if model_type == 'lgb':
        if plot_feature_importance:
            feature_importance["importance"] /= n_fold
            cols = feature_importance[["feature", "importance"]].groupby("feature").mean().sort_values(
                by="importance", ascending=False)[:50].index

            best_features = feature_importance.loc[feature_importance.feature.isin(cols)]

            plt.figure(figsize=(16, 12));
            sns.barplot(x="importance", y="feature", data=best_features.sort_values(by="importance", ascending=False));
            plt.title('LGB Features (avg over folds)');
        
            return oof, prediction, feature_importance
        return oof, prediction, scores
    
    else:
        return oof, prediction, scores

# %% [markdown]
# ## First model

# %%
params = {'num_leaves': 128,
          'min_child_samples': 79,
          'objective': 'gamma',
          'max_depth': -1,
          'learning_rate': 0.01,
          "boosting_type": "gbdt",
          "subsample_freq": 5,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1302650970728192,
          'reg_lambda': 0.3603427518866501,
          'colsample_bytree': 0.1
         }
oof_lgb, prediction_lgb, feature_importance = train_model(X, X_test, y, params=params, folds=folds, model_type='lgb', plot_feature_importance=True)
# Out:
# Fold 0 started at Tue Apr 30 22:46:37 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [664]	training's l1: 1.23868	valid_1's l1: 2.09886
# Fold 1 started at Tue Apr 30 22:46:43 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [805]	training's l1: 1.13921	valid_1's l1: 2.00676
# Fold 2 started at Tue Apr 30 22:46:50 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [550]	training's l1: 1.33611	valid_1's l1: 2.15575
# Fold 3 started at Tue Apr 30 22:46:56 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [451]	training's l1: 1.46945	valid_1's l1: 1.94486
# Fold 4 started at Tue Apr 30 22:47:01 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [579]	training's l1: 1.32006	valid_1's l1: 2.07496
# CV mean score: 2.0562, std: 0.0734.

# %%
submission = pd.read_csv('../input/sample_submission.csv', index_col='seg_id')
submission['time_to_failure'] = prediction_lgb
print(submission.head())
submission.to_csv('submission.csv')
# Out:
#               time_to_failure
# seg_id
# seg_00030f  3.807483780670808
# seg_0012b5  4.612386043368744
# seg_00184e  5.369009259491488
# seg_003339  8.481809609691428
# seg_0042cc  6.987774349554972

# %%
sub1 = pd.read_csv('../input/lanl-features/submission_1.csv')
sub1.to_csv('submission_1.csv', index=False)

# %% [markdown]
# ## NN features
# Here I normalize the data and create features using NearestNeighbors. The idea is to find samples which are similar and use it to generate features.

# %%
scaler = StandardScaler()
scaler.fit(X)
X_train_scaled = pd.DataFrame(scaler.transform(X), columns=X.columns)
X_test_scaled = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %%
# %%time
n = 10
neigh = NearestNeighbors(n, n_jobs=-1)
neigh.fit(X_train_scaled)

dists, _ = neigh.kneighbors(X_train_scaled, n_neighbors=n)
mean_dist = dists.mean(axis=1)
max_dist = dists.max(axis=1)
min_dist = dists.min(axis=1)

X_train_scaled['mean_dist'] = mean_dist
X_train_scaled['max_dist'] = max_dist
X_train_scaled['min_dist'] = min_dist

test_dists, _ = neigh.kneighbors(X_test_scaled, n_neighbors=n)

test_mean_dist = test_dists.mean(axis=1)
test_max_dist = test_dists.max(axis=1)
test_min_dist = test_dists.min(axis=1)

X_test_scaled['mean_dist'] = test_mean_dist
X_test_scaled['max_dist'] = test_max_dist
X_test_scaled['min_dist'] = test_min_dist
# Out:
# CPU times: user 5min 10s, sys: 93.1 ms, total: 5min 10s
# Wall time: 10.4 s

# %%
params = {'num_leaves': 32,
          'min_data_in_leaf': 79,
          'objective': 'gamma',
          'max_depth': -1,
          'learning_rate': 0.01,
          "boosting": "gbdt",
          "bagging_freq": 5,
          "bagging_fraction": 0.8126672064208567,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1302650970728192,
          'reg_lambda': 0.3603427518866501,
          'feature_fraction': 0.1
         }
oof_lgb, prediction_lgb, feature_importance = train_model(X_train_scaled, X_test_scaled, y, params=params, folds=folds, model_type='lgb', plot_feature_importance=True)
# Out:
# Fold 0 started at Tue Apr 30 22:48:50 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [626]	training's l1: 1.33564	valid_1's l1: 2.09692
# Fold 1 started at Tue Apr 30 22:48:55 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [983]	training's l1: 1.08657	valid_1's l1: 2.00284
# Fold 2 started at Tue Apr 30 22:49:02 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [408]	training's l1: 1.5359	valid_1's l1: 2.15788
# Fold 3 started at Tue Apr 30 22:49:06 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [396]	training's l1: 1.58713	valid_1's l1: 1.93662
# Fold 4 started at Tue Apr 30 22:49:10 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [294]	training's l1: 1.67626	valid_1's l1: 2.07807
# CV mean score: 2.0545, std: 0.0769.

# %%
submission['time_to_failure'] = prediction_lgb
submission.to_csv('submission_nn.csv')

# %% [markdown]
# ## Model interpretation

# %% [markdown]
# ### ELI5 and permutation importance
# ELI5 is a package with provides explanations for ML models. It can do this not only for linear models, but also for tree based like Random Forest or lightgbm.
#
# **Important notice**: running eli5 on all features takes a lot of time, so I run the cell below in `version 14` and printed the top-50 features. In the following versions I'll use these 50 columns and use eli5 to find top-40 of them so that it takes less time

# %%
top_columns = ['iqr1_denoised', 'percentile_5_denoised', 'abs_percentile_90_denoised', 'percentile_95_denoised', 'ave_roll_std_10', 'num_peaks_10', 'percentile_roll_std_20',
               'ratio_unique_values_denoised', 'fftr_percentile_roll_std_75_denoised', 'num_crossing_0_denoised', 'percentile_95', 'ffti_percentile_roll_std_75_denoised',
               'min_roll_std_10000', 'percentile_roll_std_1', 'percentile_roll_std_10', 'fftr_percentile_roll_std_70_denoised', 'ave_roll_std_50', 'ffti_percentile_roll_std_70_denoised',
               'exp_Moving_std_300_mean_denoised', 'ffti_percentile_roll_std_30_denoised', 'mean_change_rate', 'percentile_roll_std_5', 'range_-1000_0', 'mad',
               'fftr_range_1000_2000_denoised', 'percentile_10_denoised', 'ffti_percentile_roll_std_80', 'percentile_roll_std_25', 'fftr_percentile_10_denoised',
               'ffti_range_-2000_-1000_denoised', 'autocorrelation_5', 'min_roll_std_100', 'fftr_percentile_roll_std_80', 'min_roll_std_500', 'min_roll_std_50', 'min_roll_std_1000',
               'ffti_percentile_20_denoised', 'iqr1', 'classic_sta_lta5_mean_denoised', 'classic_sta_lta6_mean_denoised', 'percentile_roll_std_10_denoised',
               'fftr_percentile_70_denoised', 'ffti_c3_50_denoised', 'ffti_percentile_roll_std_75', 'abs_percentile_90', 'range_0_1000', 'spkt_welch_density_50_denoised',
               'ffti_percentile_roll_std_40_denoised', 'ffti_range_-4000_-3000', 'mean_change_rate_last_50000']


X_train, X_valid, y_train, y_valid = train_test_split(X[top_columns], y, test_size=0.1)
model = lgb.LGBMRegressor(**params, n_estimators = 50000, n_jobs = -1, verbose=-1)
model.fit(X_train, y_train, 
        eval_set=[(X_train, y_train), (X_valid, y_valid)], eval_metric='mae',
        verbose=10000, early_stopping_rounds=200)

perm = eli5.sklearn.PermutationImportance(model, random_state=1).fit(X_train, y_train)
# Out:
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [800]	training's l1: 1.67847	valid_1's l1: 2.01842

# %%
eli5.show_weights(perm, top=50, feature_names=top_columns)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0485
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num_crossing_0_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0285
#
#                     &plusmn; 0.0021
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 num_peaks_10
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0220
#
#                     &plusmn; 0.0054
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 abs_percentile_90_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.25%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0200
#
#                     &plusmn; 0.0031
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 percentile_roll_std_5
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.76%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0161
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 percentile_5_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.20%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0150
#
#                     &plusmn; 0.0013
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 percentile_roll_std_1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.36%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0146
#
#                     &plusmn; 0.0020
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 percentile_roll_std_10
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0143
#
#                     &plusmn; 0.0015
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 min_roll_std_500
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.52%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0142
#
#                     &plusmn; 0.0019
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 min_roll_std_50
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.11%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0128
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 percentile_95_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0128
#
#                     &plusmn; 0.0012
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 iqr1_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.30%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0124
#
#                     &plusmn; 0.0016
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 min_roll_std_10000
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.38%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0122
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 classic_sta_lta6_mean_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0120
#
#                     &plusmn; 0.0011
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 min_roll_std_100
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0115
#
#                     &plusmn; 0.0018
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ffti_percentile_roll_std_80
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.81%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0112
#
#                     &plusmn; 0.0017
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 ffti_percentile_roll_std_75
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.97%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0109
#
#                     &plusmn; 0.0010
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 classic_sta_lta5_mean_denoised
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.

# %%
top_features = [i for i in eli5.formatters.as_dataframe.explain_weights_df(model).feature if 'BIAS' not in i][:40]
oof_lgb, prediction_lgb, feature_importance = train_model(X[top_features], X_test[top_features], y, params=params, folds=folds, model_type='lgb', plot_feature_importance=True)
# Out:
# Fold 0 started at Tue Apr 30 22:50:02 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [663]	training's l1: 1.75132	valid_1's l1: 2.12432
# Fold 1 started at Tue Apr 30 22:50:03 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [808]	training's l1: 1.72602	valid_1's l1: 2.02862
# Fold 2 started at Tue Apr 30 22:50:04 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [764]	training's l1: 1.70524	valid_1's l1: 2.16018
# Fold 3 started at Tue Apr 30 22:50:05 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [405]	training's l1: 1.89933	valid_1's l1: 1.95229
# Fold 4 started at Tue Apr 30 22:50:06 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [325]	training's l1: 1.90291	valid_1's l1: 2.10995
# CV mean score: 2.0751, std: 0.0750.

# %%
submission['time_to_failure'] = prediction_lgb
submission.to_csv('submission_eli5.csv')

# %% [markdown]
# ## Feature selection
#
# Here I try various approaches to feature selection.
#
# **Important notice**: running feature selection on all features takes a lot of time, so I'll run some of feature selection methods and print the result, which I'll use in the following versions of the kernel, so that I can explore more approaches.

# %%
params = {'num_leaves': 32,
          'min_child_samples': 79,
          'objective': 'gamma',
          'max_depth': -1,
          'learning_rate': 0.01,
          "boosting_type": "gbdt",
          "subsample_freq": 5,
          "subsample": 0.9,
          "bagging_seed": 11,
          "metric": 'mae',
          "verbosity": -1,
          'reg_alpha': 0.1302650970728192,
          'reg_lambda': 0.3603427518866501,
          'colsample_bytree': 1.0
         }

# %% [markdown]
# ### SelectPercentile
#
# **Important notice**:  I run the cell below in `version 14` and printed the scores_dict. In the following versions I'll use `scores_dict` and plot the results instead of running feature selection each time

# %%
# %%time
# scores_dict = {'f_classif': [], 'mutual_info_classif': [], 'n_features': []}
# for i in range(5, 105, 5):
#     print(i)
#     s1 = SelectPercentile(f_classif, percentile=i)
#     X_train1 = s1.fit_transform(X, y.values.astype(int))
#     X_test1 = s1.transform(X_test)
#     oof, prediction, scores = train_model(X_train1, X_test1, y.values.reshape(-1, ), params=params, folds=folds, model_type='lgb', plot_feature_importance=False)
#     scores_dict['f_classif'].append(np.mean(scores))
    
#     s2 = SelectPercentile(mutual_info_classif, percentile=i)
#     X_train1 = s2.fit_transform(X, y.values.astype(int))
#     X_test1 = s2.transform(X_test)
#     oof, prediction, scores = train_model(X_train1, X_test1, y.values.reshape(-1, ), params=params, folds=folds, model_type='lgb', plot_feature_importance=False)
#     scores_dict['mutual_info_classif'].append(np.mean(scores))
    
#     scores_dict['n_features'].append(X_train1.shape[1])

# %%
scores_dict = {'f_classif': [2.0746468465171377, 2.0753843541953687, 2.062191535440333, 2.0654327826583034, 2.0643551320704936, 2.0617560048382675,
                             2.061565197738015, 2.0598878198917494, 2.0654865223333143, 2.0632788555735777, 2.058002635080971, 2.051075689018734,
                             2.0472543961304583, 2.052401474353084, 2.055924154798443, 2.0561794619762352, 2.0549680611994963, 2.057123777802326,
                             2.0591868861136904, 2.0577745274024553],
               'mutual_info_classif': [2.0866763775014006, 2.0745431497064324, 2.0564324832516427, 2.060125564781158, 2.067334544167612, 2.0665943783246448,
                                       2.063891669849029, 2.070194051004794, 2.0667490707700447, 2.0681653852378354, 2.0592743636982345, 2.061260741522344,
                                       2.05680667824411, 2.0565047875243003, 2.058252567141659, 2.0554927194831922, 2.0562776429736873, 2.0618179277444084,
                                       2.06364125584214, 2.0577745274024553],
               'n_features': [98, 196, 294, 392, 490, 588, 685, 783, 881, 979, 1077, 1175, 1273, 1370, 1468, 1566, 1664, 1762, 1860, 1958]}

# %%
scores_df = pd.DataFrame(scores_dict)
scores_df = scores_df.melt(id_vars=['n_features'], value_vars=['mutual_info_classif', 'f_classif'], var_name='metric', value_name='mae')
max_value = scores_df['mae'].max() * 1.05
min_value = scores_df['mae'].min() * 0.95
render(alt.Chart(scores_df).mark_line().encode(
    y=alt.Y('mae:Q', scale=alt.Scale(domain=(min_value, max_value))),
    x='n_features:O',
    color='metric:N',
    tooltip=['metric:N', 'n:O', 'mae:Q']
).properties(
    title='Top N features by SelectPercentile vs CV'
).interactive())
# Out:
#     <div id="vega-chart"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega-lite/v3.2.1.json", "config": {"mark": {"tooltip": null}, "view": {"height": 300, "width": 400}}, "data": {"name": "data-3c300f737bd277731858b5e46dfd6f4e"}, "datasets": {"data-3c300f737bd277731858b5e46dfd6f4e": [{"mae": 2.0866763775014006, "metric": "mutual_info_classif", "n_features": 98}, {"mae": 2.0745431497064324, "metric": "mutual_info_classif", "n_features": 196}, {"mae": 2.0564324832516427, "metric": "mutual_info_classif", "n_features": 294}, {"mae": 2.060125564781158, "metric": "mutual_info_classif", "n_features": 392}, {"mae": 2.067334544167612, "metric": "mutual_info_classif", "n_features": 490}, {"mae": 2.0665943783246448, "metric": "mutual_info_classif", "n_features": 588}, {"mae": 2.063891669849029, "metric": "mutual_info_classif", "n_features": 685}, {"mae": 2.070194051004794, "metric": "mutual_info_classif", "n_features": 783}, {"mae": 2.0667490707700447, "metric": "mutual_info_classif", "n_features": 881}, {"mae": 2.0681653852378354, "metric": "mutual_info_classif", "n_features": 979}, {"mae": 2.0592743636982345, "metric": "mutual_info_classif", "n_features": 1077}, {"mae": 2.061260741522344, "metric": "mutual_info_classif", "n_features": 1175}, {"mae": 2.05680667824411, "metric": "mutual_info_classif", "n_features": 1273}, {"mae": 2.0565047875243003, "metric": "mutual_info_classif", "n_features": 1370}, {"mae": 2.058252567141659, "metric": "mutual_info_classif", "n_features": 1468}, {"mae": 2.0554927194831922, "metric": "mutual_info_classif", "n_features": 1566}, {"mae": 2.0562776429736873, "metric": "mutual_info_classif", "n_features": 1664}, {"mae": 2.0618179277444084, "metric": "mutual_info_classif", "n_features": 1762}, {"mae": 2.06364125584214, "metric": "mutual_info_classif", "n_features": 1860}, {"mae": 2.0577745274024553, "metric": "mutual_info_classif", "n_features": 1958}, {"mae": 2.0746468465171377, "metric": "f_classif", "n_features": 98}, {"mae": 2.0753843541953687, "metric": "f_classif", "n_features": 196}, {"mae": 2.062191535440333, "metric": "f_classif", "n_features": 294}, {"mae": 2.0654327826583034, "metric": "f_classif", "n_features": 392}, {"mae": 2.0643551320704936, "metric": "f_classif", "n_features": 490}, {"mae": 2.0617560048382675, "metric": "f_classif", "n_features": 588}, {"mae": 2.061565197738015, "metric": "f_classif", "n_features": 685}, {"mae": 2.0598878198917494, "metric": "f_classif", "n_features": 783}, {"mae": 2.0654865223333143, "metric": "f_classif", "n_features": 881}, {"mae": 2.0632788555735777, "metric": "f_classif", "n_features": 979}, {"mae": 2.058002635080971, "metric": "f_classif", "n_features": 1077}, {"mae": 2.051075689018734, "metric": "f_classif", "n_features": 1175}, {"mae": 2.0472543961304583, "metric": "f_classif", "n_features": 1273}, {"mae": 2.052401474353084, "metric": "f_classif", "n_features": 1370}, {"mae": 2.055924154798443, "metric": "f_classif", "n_features": 1468}, {"mae": 2.0561794619762352, "metric": "f_classif", "n_features": 1566}, {"mae": 2.0549680611994963, "metric": "f_classif", "n_features": 1664}, {"mae": 2.057123777802326, "metric": "f_classif", "n_features": 1762}, {"mae": 2.0591868861136904, "metric": "f_classif", "n_features": 1860}, {"mae": 2.0577745274024553, "metric": "f_classif", "n_features": 1958}]}, "encoding": {"color": {"field": "metric", "type": "nominal"}, "tooltip": [{"field": "metric", "type": "nominal"}, {"field": "n", "type": "ordinal"}, {"field": "mae", "type": "quantitative"}], "x": {"field": "n_features", "type": "ordinal"}, "y": {"field": "mae", "scale": {"domain": [1.9448916763239352, 2.1910101963764705]}, "type": "quantitative"}}, "mark": "line", "selection": {"selector001": {"bind": "scales", "encodings": ["x", "y"], "type": "interval"}}, "title": "Top N features by SelectPercentile vs CV"};
#         vg_embed("#vega-chart", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# ### SelectKBest
#
# **Important notice**:  I run the cell below in `version 14` and printed the scores_dict. In the following versions I'll use `scores_dict` and plot the results instead of running feature selection each time

# %%
# %%time
# scores_dict = {'f_classif': [], 'mutual_info_classif': [], 'n_features': []}
# for i in np.arange(10, 1958, 100):
#     print(i)
#     s1 = SelectKBest(f_classif, k=i)
#     X_train1 = s1.fit_transform(X, y.values.astype(int))
#     X_test1 = s1.transform(X_test)
#     oof, prediction, scores = train_model(X_train1, X_test1, y.values.reshape(-1, ), params=params, folds=folds, model_type='lgb', plot_feature_importance=False)
#     scores_dict['f_classif'].append(np.mean(scores))
    
#     s2 = SelectKBest(mutual_info_classif, k=i)
#     X_train1 = s2.fit_transform(X, y.values.astype(int))
#     X_test1 = s2.transform(X_test)
#     oof, prediction, scores = train_model(X_train1, X_test1, y.values.reshape(-1, ), params=params, folds=folds, model_type='lgb', plot_feature_importance=False)
#     scores_dict['mutual_info_classif'].append(np.mean(scores))
    
#     scores_dict['n_features'].append(X_train1.shape[1])

# %%
scores_dict = {'f_classif': [2.1495892622081354, 2.0778182269587147, 2.0716153738740006, 2.06152950679902, 2.0645162758752553, 2.0627705797004032, 2.0610992303725157,
                             2.057762113735462, 2.0618360883613627, 2.0603197111525984, 2.06081274633874, 2.0580767195278056, 2.0527646572747127, 2.0498353445032533,
                             2.052442594925, 2.0564456881902133, 2.0582284644115365, 2.0558612960548635, 2.0580900016350094, 2.058218782401599],
               'mutual_info_classif': [2.1235703196243687, 2.084958198672301, 2.0596822478390955, 2.053305869981444, 2.063468853227225, 2.0674399950434323, 2.0658618511287874,
                                       2.063003703200445, 2.0653174905858664, 2.0644340327023656, 2.0748993062333523, 2.0587602096358113, 2.0601495560836076, 2.0559629138548603,
                                       2.0553852701221134, 2.058022171415446, 2.060755947658241, 2.057916705462307, 2.056245795262636, 2.0580691870837056],
               'n_features': [10, 110, 210, 310, 410, 510, 610, 710, 810, 910, 1010, 1110, 1210, 1310, 1410, 1510, 1610, 1710, 1810, 1910]}

# %%
scores_df = pd.DataFrame(scores_dict)
scores_df = scores_df.melt(id_vars=['n_features'], value_vars=['mutual_info_classif', 'f_classif'], var_name='metric', value_name='mae')
max_value = scores_df['mae'].max() * 1.05
min_value = scores_df['mae'].min() * 0.95
render(alt.Chart(scores_df).mark_line().encode(
    y=alt.Y('mae:Q', scale=alt.Scale(domain=(min_value, max_value))),
    x='n_features:O',
    color='metric:N',
    tooltip=['metric:N', 'n:O', 'mae:Q']
).properties(
    title='Top N features by SelectKBest vs CV'
).interactive())
# Out:
#     <div id="vega-chart-1"></div><script>
#     require(["vega-embed"], function(vg_embed) {
#         const spec = {"$schema": "https://vega.github.io/schema/vega-lite/v3.2.1.json", "config": {"mark": {"tooltip": null}, "view": {"height": 300, "width": 400}}, "data": {"name": "data-602802a6521057f4d1c12eb9331f076b"}, "datasets": {"data-602802a6521057f4d1c12eb9331f076b": [{"mae": 2.1235703196243687, "metric": "mutual_info_classif", "n_features": 10}, {"mae": 2.084958198672301, "metric": "mutual_info_classif", "n_features": 110}, {"mae": 2.0596822478390955, "metric": "mutual_info_classif", "n_features": 210}, {"mae": 2.053305869981444, "metric": "mutual_info_classif", "n_features": 310}, {"mae": 2.063468853227225, "metric": "mutual_info_classif", "n_features": 410}, {"mae": 2.0674399950434323, "metric": "mutual_info_classif", "n_features": 510}, {"mae": 2.0658618511287874, "metric": "mutual_info_classif", "n_features": 610}, {"mae": 2.063003703200445, "metric": "mutual_info_classif", "n_features": 710}, {"mae": 2.0653174905858664, "metric": "mutual_info_classif", "n_features": 810}, {"mae": 2.0644340327023656, "metric": "mutual_info_classif", "n_features": 910}, {"mae": 2.0748993062333523, "metric": "mutual_info_classif", "n_features": 1010}, {"mae": 2.0587602096358113, "metric": "mutual_info_classif", "n_features": 1110}, {"mae": 2.0601495560836076, "metric": "mutual_info_classif", "n_features": 1210}, {"mae": 2.0559629138548603, "metric": "mutual_info_classif", "n_features": 1310}, {"mae": 2.0553852701221134, "metric": "mutual_info_classif", "n_features": 1410}, {"mae": 2.058022171415446, "metric": "mutual_info_classif", "n_features": 1510}, {"mae": 2.060755947658241, "metric": "mutual_info_classif", "n_features": 1610}, {"mae": 2.057916705462307, "metric": "mutual_info_classif", "n_features": 1710}, {"mae": 2.056245795262636, "metric": "mutual_info_classif", "n_features": 1810}, {"mae": 2.0580691870837056, "metric": "mutual_info_classif", "n_features": 1910}, {"mae": 2.1495892622081354, "metric": "f_classif", "n_features": 10}, {"mae": 2.0778182269587147, "metric": "f_classif", "n_features": 110}, {"mae": 2.0716153738740006, "metric": "f_classif", "n_features": 210}, {"mae": 2.06152950679902, "metric": "f_classif", "n_features": 310}, {"mae": 2.0645162758752553, "metric": "f_classif", "n_features": 410}, {"mae": 2.0627705797004032, "metric": "f_classif", "n_features": 510}, {"mae": 2.0610992303725157, "metric": "f_classif", "n_features": 610}, {"mae": 2.057762113735462, "metric": "f_classif", "n_features": 710}, {"mae": 2.0618360883613627, "metric": "f_classif", "n_features": 810}, {"mae": 2.0603197111525984, "metric": "f_classif", "n_features": 910}, {"mae": 2.06081274633874, "metric": "f_classif", "n_features": 1010}, {"mae": 2.0580767195278056, "metric": "f_classif", "n_features": 1110}, {"mae": 2.0527646572747127, "metric": "f_classif", "n_features": 1210}, {"mae": 2.0498353445032533, "metric": "f_classif", "n_features": 1310}, {"mae": 2.052442594925, "metric": "f_classif", "n_features": 1410}, {"mae": 2.0564456881902133, "metric": "f_classif", "n_features": 1510}, {"mae": 2.0582284644115365, "metric": "f_classif", "n_features": 1610}, {"mae": 2.0558612960548635, "metric": "f_classif", "n_features": 1710}, {"mae": 2.0580900016350094, "metric": "f_classif", "n_features": 1810}, {"mae": 2.058218782401599, "metric": "f_classif", "n_features": 1910}]}, "encoding": {"color": {"field": "metric", "type": "nominal"}, "tooltip": [{"field": "metric", "type": "nominal"}, {"field": "n", "type": "ordinal"}, {"field": "mae", "type": "quantitative"}], "x": {"field": "n_features", "type": "ordinal"}, "y": {"field": "mae", "scale": {"domain": [1.9473435772780905, 2.2570687253185424]}, "type": "quantitative"}}, "mark": "line", "selection": {"selector002": {"bind": "scales", "encodings": ["x", "y"], "type": "interval"}}, "title": "Top N features by SelectKBest vs CV"};
#         vg_embed("#vega-chart-1", spec, {defaultStyle: true}).catch(console.warn);
#         console.log("anything?");
#     });
#     console.log("really...anything?");
#     </script>

# %% [markdown]
# ### Dropping highly correlated features
#
# Due to the huge number of features there are certainly some highly correlated features, let's try droping them!

# %%
# https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/
corr_matrix = X.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.99)]
X = X.drop(to_drop, axis=1)
X_test = X_test.drop(to_drop, axis=1)
oof_lgb, prediction_lgb, feature_importance = train_model(X, X_test, y, params=params, folds=folds, model_type='lgb', plot_feature_importance=True)
# Out:
# Fold 0 started at Tue Apr 30 22:51:33 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [545]	training's l1: 1.21918	valid_1's l1: 2.08756
# Fold 1 started at Tue Apr 30 22:51:42 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [654]	training's l1: 1.11553	valid_1's l1: 2.01298
# Fold 2 started at Tue Apr 30 22:51:53 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [327]	training's l1: 1.4767	valid_1's l1: 2.15877
# Fold 3 started at Tue Apr 30 22:52:00 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [285]	training's l1: 1.57669	valid_1's l1: 1.94203
# Fold 4 started at Tue Apr 30 22:52:06 2019
# Training until validation scores don't improve for 200 rounds.
# Early stopping, best iteration is:
# [403]	training's l1: 1.38641	valid_1's l1: 2.06779
# CV mean score: 2.0538, std: 0.0728.

# %%
submission['time_to_failure'] = prediction_lgb
submission.to_csv('submission_no_corr.csv')

# %% [markdown]
# ### RFE
#
#
# **Important notice**:  I run the cell below in `version 18` and printed the scores_dict. In the following versions I'll use `scores_dict` and plot the results instead of running feature selection each time

# %%
# %%time
# scores_dict = {'rfe_score': [], 'n_features': []}
# for i in np.arange(10, 1958, 100)[:3]:
#     print(i)
#     s1 = RFE(model, i, step=100)
#     X_train1 = s1.fit_transform(X, y.values.astype(int))
#     X_test1 = s1.transform(X_test)
#     oof, prediction, scores = train_model(X_train1, X_test1, y.values.reshape(-1, ), params=params, folds=folds, model_type='lgb', plot_feature_importance=False)
#     scores_dict['rfe_score'].append(np.mean(scores))
    
#     scores_dict['n_features'].append(X_train1.shape[1])

# %%
scores_df = {'rfe_score': [2.103586938061856, 2.052535910798748, 2.053228199447811], 'n_features': [10, 110, 210]}

# %%
scores_df = pd.DataFrame(scores_dict)
scores_df = scores_df.melt(id_vars=['n_features'], value_vars=['rfe_score'], var_name='metric', value_name='mae')
max_value = scores_df['mae'].max() * 1.05
min_value = scores_df['mae'].min() * 0.95
render(alt.Chart(scores_df).mark_line().encode(
    y=alt.Y('mae:Q', scale=alt.Scale(domain=(min_value, max_value))),
    x='n_features:O',
    color='metric:N',
    tooltip=['metric:N', 'n:O', 'mae:Q']
).properties(
    title='Top N features by SelectKBest vs CV'
).interactive())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-76f6947e5370> in <module>
#       1 scores_df = pd.DataFrame(scores_dict)
# ----> 2 scores_df = scores_df.melt(id_vars=['n_features'], value_vars=['rfe_score'], var_name='metric', value_name='mae')
#       3 max_value = scores_df['mae'].max() * 1.05
#       4 min_value = scores_df['mae'].min() * 0.95
#       5 render(alt.Chart(scores_df).mark_line().encode(
#
# /local/user/toolse64/ubuntu/18.04/usr/local/tools/anaconda_2018.12/lib/python3.7/site-packages/pandas/core/frame.py in melt(self, id_vars, value_vars, var_name, value_name, col_level)
#    6092         return melt(self, id_vars=id_vars, value_vars=value_vars,
#    6093                     var_name=var_name, value_name=value_name,
# -> 6094                     col_level=col_level)
#    6095
#    6096     # ----------------------------------------------------------------------
#
# /local/user/toolse64/ubuntu/18.04/usr/local/tools/anaconda_2018.12/lib/python3.7/site-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level)
#      64                 raise KeyError("The following 'value_vars' are not present in"
#      65                                " the DataFrame: {missing}"
# ---> 66                                "".format(missing=list(missing)))
#      67         frame = frame.loc[:, id_vars + value_vars]
#      68     else:
#
# KeyError: "The following 'value_vars' are not present in the DataFrame: ['rfe_score']"

# %% [markdown]
# ## Model comparison
#
# In this section I'll try variuos sklearn models and compair their score. Running GridSearchCV each time is too long, so I'll run it once for each model and use optimal parameters.

# %%
# %%time
rfr = RandomForestRegressor()

# parameter_grid = {'n_estimators': [50, 60],
#                   'max_depth': [5, 10]
#                  }

# grid_search = GridSearchCV(rfr, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
# grid_search.fit(X, y)
# print('Best score: {}'.format(grid_search.best_score_))
# print('Best parameters: {}'.format(grid_search.best_params_))
# rfr = RandomForestRegressor(**grid_search.best_params_)
rfr = RandomForestRegressor(n_estimators=50, max_depth=5)
oof_rfr, prediction_rfr, scores_rfr = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=rfr)
print(scores_rfr)
# Out:
# Fold 0 started at Tue Apr 30 04:40:10 2019
# Fold 0. MAE: 2.1504.
#
# Fold 1 started at Tue Apr 30 04:40:49 2019
# Fold 1. MAE: 2.0749.
#
# Fold 2 started at Tue Apr 30 04:41:28 2019
# Fold 2. MAE: 2.1869.
#
# Fold 3 started at Tue Apr 30 04:42:07 2019
# Fold 3. MAE: 1.9980.
#
# Fold 4 started at Tue Apr 30 04:42:46 2019
# Fold 4. MAE: 2.1121.
#
# CV mean score: 2.1045, std: 0.0651.
# [2.1503931162887686, 2.0748880601331465, 2.186943022187642, 1.9979647478208087, 2.112140917337223]
# CPU times: user 3min 15s, sys: 620 ms, total: 3min 15s
# Wall time: 3min 15s

# %%
# %%time
linreg = linear_model.LinearRegression(normalize=True, copy_X=True, n_jobs=-1)

# parameter_grid = {'n_estimators': [50, 60],
#                   'max_depth': [5, 10]
#                  }

# grid_search = GridSearchCV(rfr, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
# grid_search.fit(X, y)
# print('Best score: {}'.format(grid_search.best_score_))
# print('Best parameters: {}'.format(grid_search.best_params_))
# rfr = RandomForestRegressor(**grid_search.best_params_)
# rfr = RandomForestRegressor(n_estimators=50, max_depth=5)
oof_linreg, prediction_linreg, scores_linreg = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=linreg)
# print(scores_linreg)
# Out:
# Fold 0 started at Tue Apr 30 04:43:25 2019
# Fold 0. MAE: 41.2041.
#
# Fold 1 started at Tue Apr 30 04:43:27 2019
# Fold 1. MAE: 296192.8946.
#
# Fold 2 started at Tue Apr 30 04:43:27 2019
# Fold 2. MAE: 50.9322.
#
# Fold 3 started at Tue Apr 30 04:43:28 2019
# Fold 3. MAE: 2006.9246.
#
# Fold 4 started at Tue Apr 30 04:43:29 2019
# Fold 4. MAE: 2371.2487.
#
# CV mean score: 60132.6408, std: 118034.0741.
# CPU times: user 6.26 s, sys: 3.25 s, total: 9.52 s
# Wall time: 4.69 s

# %%
# %%time
ridge = linear_model.Ridge(normalize=True)

parameter_grid = {'alpha': [0.1, 1.0, 10.0]}

grid_search = GridSearchCV(ridge, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
grid_search.fit(X, y)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
ridge = linear_model.Ridge(**grid_search.best_params_, normalize=True)
oof_ridge, prediction_ridge, scores_ridge = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=ridge)
# print(scores_ridge)
# Out:
# Best score: -2.148000446396182
# Best parameters: {'alpha': 1.0}
# Fold 0 started at Tue Apr 30 04:43:43 2019
# Fold 0. MAE: 2.1765.
#
# Fold 1 started at Tue Apr 30 04:43:44 2019
# Fold 1. MAE: 2.1246.
#
# Fold 2 started at Tue Apr 30 04:43:44 2019
# Fold 2. MAE: 2.2160.
#
# Fold 3 started at Tue Apr 30 04:43:45 2019
# Fold 3. MAE: 2.0088.
#
# Fold 4 started at Tue Apr 30 04:43:46 2019
# Fold 4. MAE: 2.2141.
#
# CV mean score: 2.1480, std: 0.0771.
# CPU times: user 5.66 s, sys: 5.84 s, total: 11.5 s
# Wall time: 16.5 s

# %%
# %%time
sgd = linear_model.SGDRegressor()

parameter_grid = {'loss': ['squared_loss', 'huber'],
                  'penalty': ['l1', 'l2', 'elasticnet'],
                  'alpha': [0.001, 0.01],
                  'l1_ratio': [0, 0.15, 0.5, 1.0],
                  'learning_rate': ['optimal', 'invscaling', 'adaptive']
                 }

grid_search = GridSearchCV(sgd, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
grid_search.fit(X, y)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
sgd = linear_model.SGDRegressor(**grid_search.best_params_)
oof_sgd, prediction_sgd, scores_sgd = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=sgd)
# Out:
# Best score: -1.6947590614606385e+32
# Best parameters: {'alpha': 0.01, 'l1_ratio': 0.5, 'learning_rate': 'invscaling', 'loss': 'huber', 'penalty': 'elasticnet'}
# Fold 0 started at Tue Apr 30 04:49:10 2019
# Fold 0. MAE: 324050034583575382107706871513088.0000.
#
# Fold 1 started at Tue Apr 30 04:49:11 2019
# Fold 1. MAE: 1231060361379920079397545788309504.0000.
#
# Fold 2 started at Tue Apr 30 04:49:12 2019
# Fold 2. MAE: 1021301041918014856358701677150208.0000.
#
# Fold 3 started at Tue Apr 30 04:49:13 2019
# Fold 3. MAE: 25477941271764544469965176045568.0000.
#
# Fold 4 started at Tue Apr 30 04:49:14 2019
# Fold 4. MAE: 437412466498079124420944421978112.0000.
#
# CV mean score: 607860369130270779336574277517312.0000, std: 449017038883990196712062953979904.0000.
# CPU times: user 10.5 s, sys: 3.6 s, total: 14.1 s
# Wall time: 5min 28s

# %%
# %%time
knn = neighbors.KNeighborsRegressor()

parameter_grid = {'n_neighbors': [50, 100]}

grid_search = GridSearchCV(knn, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
grid_search.fit(X, y)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
knn = neighbors.KNeighborsRegressor(**grid_search.best_params_)
oof_knn, prediction_knn, scores_knn = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=knn)
# Out:
# Best score: -2.386296024679084
# Best parameters: {'n_neighbors': 100}
# Fold 0 started at Tue Apr 30 04:49:27 2019
# Fold 0. MAE: 2.4430.
#
# Fold 1 started at Tue Apr 30 04:49:29 2019
# Fold 1. MAE: 2.3574.
#
# Fold 2 started at Tue Apr 30 04:49:32 2019
# Fold 2. MAE: 2.4659.
#
# Fold 3 started at Tue Apr 30 04:49:34 2019
# Fold 3. MAE: 2.2854.
#
# Fold 4 started at Tue Apr 30 04:49:36 2019
# Fold 4. MAE: 2.3797.
#
# CV mean score: 2.3863, std: 0.0642.
# CPU times: user 12 s, sys: 684 ms, total: 12.6 s
# Wall time: 23.5 s

# %%
# %%time
lasso = linear_model.Lasso(normalize=True)

parameter_grid = {'alpha': [0.1, 1.0, 10.0]}

grid_search = GridSearchCV(lasso, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
grid_search.fit(X, y)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
lasso = linear_model.Lasso(**grid_search.best_params_, normalize=True)
oof_lasso, prediction_lasso, scores_lasso = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=lasso)
# Out:
# Best score: -3.048578606466069
# Best parameters: {'alpha': 0.1}
# Fold 0 started at Tue Apr 30 04:49:45 2019
# Fold 0. MAE: 3.1293.
#
# Fold 1 started at Tue Apr 30 04:49:46 2019
# Fold 1. MAE: 3.1061.
#
# Fold 2 started at Tue Apr 30 04:49:47 2019
# Fold 2. MAE: 3.0267.
#
# Fold 3 started at Tue Apr 30 04:49:47 2019
# Fold 3. MAE: 2.9735.
#
# Fold 4 started at Tue Apr 30 04:49:48 2019
# Fold 4. MAE: 3.0073.
#
# CV mean score: 3.0486, std: 0.0594.
# CPU times: user 4.01 s, sys: 3.53 s, total: 7.54 s
# Wall time: 10.2 s

# %%
# %%time
etr = ExtraTreesRegressor()

parameter_grid = {'n_estimators': [100, 200, 500],
                  'max_depth': [5, 10, 20]
                 }

grid_search = GridSearchCV(rfr, param_grid=parameter_grid, cv=folds, scoring='neg_mean_absolute_error', n_jobs=-1)
grid_search.fit(X, y)
print('Best score: {}'.format(grid_search.best_score_))
print('Best parameters: {}'.format(grid_search.best_params_))
etr = ExtraTreesRegressor(**grid_search.best_params_)
oof_etr, prediction_etr, scores_etr = train_model(X, X_test, y, params=params, folds=folds, model_type='sklearn', model=etr)
# Out:
# Best score: -2.094005506102466
# Best parameters: {'max_depth': 10, 'n_estimators': 500}
# Fold 0 started at Tue Apr 30 06:58:53 2019
# Fold 0. MAE: 2.1527.
#
# Fold 1 started at Tue Apr 30 07:01:03 2019
# Fold 1. MAE: 2.0775.
#
# Fold 2 started at Tue Apr 30 07:03:05 2019
# Fold 2. MAE: 2.1697.
#
# Fold 3 started at Tue Apr 30 07:05:17 2019
# Fold 3. MAE: 1.9933.
#
# Fold 4 started at Tue Apr 30 07:07:24 2019
# Fold 4. MAE: 2.0909.
#
# CV mean score: 2.0968, std: 0.0626.
# CPU times: user 26min 14s, sys: 1.46 s, total: 26min 15s
# Wall time: 2h 19min 46s
